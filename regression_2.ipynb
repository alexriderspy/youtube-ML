# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("../data/Simple LR/Salary_dataset.csv")
X = ds["YearsExperience"].values
Y = ds["Salary"].values

# %%
X
# Out:
# array([ 1.2,  1.4,  1.6,  2.1,  2.3,  3. ,  3.1,  3.3,  3.3,  3.8,  4. ,
#         4.1,  4.1,  4.2,  4.6,  5. ,  5.2,  5.4,  6. ,  6.1,  6.9,  7.2,
#         8. ,  8.3,  8.8,  9.1,  9.6,  9.7, 10.4, 10.6])

# %%
Y
# Out:
# array([ 39344.,  46206.,  37732.,  43526.,  39892.,  56643.,  60151.,
#         54446.,  64446.,  57190.,  63219.,  55795.,  56958.,  57082.,
#         61112.,  67939.,  66030.,  83089.,  81364.,  93941.,  91739.,
#         98274., 101303., 113813., 109432., 105583., 116970., 112636.,
#        122392., 121873.])

# %%
plt.plot(X,Y)

# %%
X = np.array(X)
Y = np.array(Y)

# %%
def mean(X):
    return np.sum(X)/len(X)

# %%
def variance(X):
    mean_value = mean(X)
    return np.sum((X-mean_value)**2)/len(X)

# %%
def norm(X):
    mean_value = mean(X)
    variance_value = variance(X)
    return (X - mean_value)/np.sqrt(variance_value)

# %%
X_norm = norm(X)

# %%
X_norm
# Out:
# array([-1.51005294, -1.43837321, -1.36669348, -1.18749416, -1.11581443,
#        -0.86493538, -0.82909552, -0.75741579, -0.75741579, -0.57821647,
#        -0.50653674, -0.47069688, -0.47069688, -0.43485702, -0.29149756,
#        -0.1481381 , -0.07645838, -0.00477865,  0.21026054,  0.2461004 ,
#         0.53281931,  0.6403389 ,  0.92705781,  1.03457741,  1.21377673,
#         1.32129632,  1.50049564,  1.5363355 ,  1.78721455,  1.85889428])

# %%
plt.plot(X_norm,Y)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/sreemanti/Documents/youtube/youtube-teach/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/sreemanti/Documents/youtube/youtube-teach/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sreemanti/Documents/youtube/youtube-teach/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sreemanti/Documents/youtube/youtube-teach/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sreemanti/Documents/youtube/youtube-teach/lib/python3.12/site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.linear_model import LinearRegression

# %%
X_norm = X_norm.reshape(-1,1)

# %%
reg = LinearRegression().fit(X_norm, Y)

# %%
reg.score(X_norm, Y)
# Out:
# 0.9569566641435086

# %%
reg.coef_
# Out:
# array([26367.18244354])

# %%
reg.intercept_
# Out:
# 76003.99999999999

# %%
y_pred = reg.predict(X_norm)

# %%
y_pred
# Out:
# array([ 36188.15875227,  38078.15121656,  39968.14368085,  44693.12484158,
#         46583.11730587,  53198.09093089,  54143.08716303,  56033.07962732,
#         56033.07962732,  60758.06078805,  62648.05325234,  63593.04948449,
#         63593.04948449,  64538.04571663,  68318.03064522,  72098.0155738 ,
#         73988.00803809,  75878.00050238,  81547.97789525,  82492.9741274 ,
#         90052.94398456,  92887.932681  , 100447.90253816, 103282.8912346 ,
#        108007.87239533, 110842.86109176, 115567.84225249, 116512.83848464,
#        123127.81210966, 125017.80457395])

# %%
plt.plot(X_norm, Y)
plt.plot(X_norm, y_pred)
